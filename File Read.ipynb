# %%
import pandas as pd

data =pd.read_csv("InfosysTestData.csv",sep=";")

# %%
data.head()
# Out:
#    source_id first_name last_name               email employment_status  \
# 0     218979      Alvin     Myers       to@mawibvu.bm                 X
# 1     537717        Ola      Owen    zefawta@kibhe.bh                 E
# 2     891825    Timothy   Fleming    wucpi@mahalif.aw                 X
# 3     828835       Tony  Chambers  pitwub@zacfaaga.jm                 X
# 4     950069       Alex   Goodwin      nazte@casna.mc                 E
#
#    is_active job_title job_role department_name sub_department_name  ...  \
# 0      False  gusipcad      DIR           bicge                 muk  ...
# 1       True     cajis     NOBA             sun              ahnaza  ...
# 2       True        he        6              ic           hijditkol  ...
# 3       True    situge        2             fom                 bub  ...
# 4      False       jel        4            haef                wafo  ...
#
#   job_start_date job_end_date company_code has_managerial_role travel_country  \
# ...
